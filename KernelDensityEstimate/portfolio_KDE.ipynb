# %%
import csv
import numpy as np
import numpy.matlib
import pandas as pd
import scipy.sparse.linalg as ll
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from sklearn import preprocessing
from scipy.stats import gaussian_kde as kde
from matplotlib import cm
from scipy import stats
from sklearn.neighbors import KernelDensity
from scipy.stats import norm
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
# load dataset
path = 'n90pol.csv'

data = pd.read_csv(path,header=0).to_numpy()
y = data[:,2]
# data.shape is (90,2)
data = data[:,:2]
df = pd.read_csv("n90pol.csv")
amy = df["amygdala"].values
acc = df["acc"].values
orient = df['orientation'].values

# %%
#data

# %%
##a.

sns.kdeplot(df["amygdala"],df["acc"], cmap="mako")
# Out:
# C:\Users\rebec\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(df["amygdala"],kde = True)

# %%
sns.distplot(df["acc"],kde = True)
# Out:
# C:\Users\rebec\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
###Maybedelete this
g = (sns.jointplot(acc,amy,color="k").plot_joint(sns.kdeplot, zorder=0, n_levels=5))
# Out:
# C:\Users\rebec\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# for 2 dimensional data
min_data = min(amy)#pdata.min(0)
max_data = max(amy)#pdata.max(0)
nbin =9    # you can change the number of bins in each dimension
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
hist, xedges, yedges = np.histogram2d(amy, acc, bins=nbin)
xpos, ypos = np.meshgrid(xedges[:-1]+xedges[1:], yedges[:-1]+yedges[1:])
xpos = xpos.flatten()/2.
ypos = ypos.flatten()/2.
zpos = np.zeros_like (xpos)
dx = xedges [1] - xedges [0]
dy = yedges [1] - yedges [0]
dz = hist.flatten()
ax.bar3d(xpos, ypos, zpos, dx, dy, dz,color='skyblue' )
plt.title("Bins = 9", fontsize=30)
plt.xlabel("Amygdala",fontsize=20)
plt.ylabel("Acc",fontsize=20)
#plt.savefig("Your_title_goes_here")
plt.show()

# %%
# for 2 dimensional data
min_data = min(amy)#pdata.min(0)
max_data = max(amy)#pdata.max(0)
nbin =5    # you can change the number of bins in each dimension
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
hist, xedges, yedges = np.histogram2d(amy, acc, bins=nbin)
xpos, ypos = np.meshgrid(xedges[:-1]+xedges[1:], yedges[:-1]+yedges[1:])
xpos = xpos.flatten()/2.
ypos = ypos.flatten()/2.
zpos = np.zeros_like (xpos)
dx = xedges [1] - xedges [0]
dy = yedges [1] - yedges [0]
dz = hist.flatten()
ax.bar3d(xpos, ypos, zpos, dx, dy, dz,color='skyblue' )
plt.title("Bins = 5", fontsize=30)
plt.xlabel("Amygdala",fontsize=20)
plt.ylabel("Acc",fontsize=20)
#plt.savefig("Your_title_goes_here")
plt.show()

# %%
# for 2 dimensional data
min_data = min(amy)#pdata.min(0)
max_data = max(amy)#pdata.max(0)
nbin =7    # you can change the number of bins in each dimension
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
hist, xedges, yedges = np.histogram2d(amy, acc, bins=nbin)
xpos, ypos = np.meshgrid(xedges[:-1]+xedges[1:], yedges[:-1]+yedges[1:])
xpos = xpos.flatten()/2.
ypos = ypos.flatten()/2.
zpos = np.zeros_like (xpos)
dx = xedges [1] - xedges [0]
dy = yedges [1] - yedges [0]
dz = hist.flatten()
ax.bar3d(xpos, ypos, zpos, dx, dy, dz,color='skyblue' )
plt.title("Bins = 7", fontsize=30)
plt.xlabel("Amygdala",fontsize=20)
plt.ylabel("Acc",fontsize=20)
#plt.savefig("Your_title_goes_here")
plt.show()

# %%
# for 2 dimensional data
min_data = min(amy)#pdata.min(0)
max_data = max(amy)#pdata.max(0)
nbin =13    # you can change the number of bins in each dimension
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
hist, xedges, yedges = np.histogram2d(amy, acc, bins=nbin)
xpos, ypos = np.meshgrid(xedges[:-1]+xedges[1:], yedges[:-1]+yedges[1:])
xpos = xpos.flatten()/2.
ypos = ypos.flatten()/2.
zpos = np.zeros_like (xpos)
dx = xedges [1] - xedges [0]
dy = yedges [1] - yedges [0]
dz = hist.flatten()
ax.bar3d(xpos, ypos, zpos, dx, dy, dz,color='skyblue' )
plt.title("Bins = 13", fontsize=30)
plt.xlabel("Amygdala",fontsize=20)
plt.ylabel("Acc",fontsize=20)
#plt.savefig("Your_title_goes_here")
plt.show()

# %%
# for 2 dimensional data
min_data = min(amy)#pdata.min(0)
max_data = max(amy)#pdata.max(0)
nbin =15    # you can change the number of bins in each dimension
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
hist, xedges, yedges = np.histogram2d(amy, acc, bins=nbin)
xpos, ypos = np.meshgrid(xedges[:-1]+xedges[1:], yedges[:-1]+yedges[1:])
xpos = xpos.flatten()/2.
ypos = ypos.flatten()/2.
zpos = np.zeros_like (xpos)
dx = xedges [1] - xedges [0]
dy = yedges [1] - yedges [0]
dz = hist.flatten()
ax.bar3d(xpos, ypos, zpos, dx, dy, dz,color='skyblue' )
plt.title("Bins = 15", fontsize=30)
plt.xlabel("Amygdala",fontsize=20)
plt.ylabel("Acc",fontsize=20)
#plt.savefig("Your_title_goes_here")
plt.show()

# %% [markdown]
# from sklearn.neighbors import KernelDensity
# kde = KernelDensity(kernel='gaussian', bandwidth=0.09).fit(data)

# %%
# Silverman's rule of thumb first.
m,n = data.shape
min_data = min(amy)#pdata.min(0)
max_data = max(amy)#pdata.max(0)
min_data_acc = min(acc)#pdata.min(0)
max_data_acc = max(acc)#pdata.max(0)
h1= 1.06*np.sqrt(np.var(data[:,:1]))*(m)**(-0.2)
# print(h1) #Output: 0.013973984566878187
nbin1 = (max_data-min_data)/h1
#print(nbin1) #--> 10.648358690240215
h2= 1.06*np.sqrt(np.var(data[:,1:2]))*(m)**(-0.2)
#print(h2) #--> 0.008758179725254514
nbin2 = (max_data_acc-min_data_acc)/h2
#print(nbin2) #--> 10.68715223211293
print(h1)
print(h2)
# Out:
# 0.013973984566878187
# 0.008758179725254514

# %%
#kernel density estimator
# create an evaluation grid
from scipy import stats
gridno = 40
min_data = data.min(0)
max_data = data.max(0)
# max_data is [0.0812 0.0559]
# min_data is [-0.0676 -0.0377]

inc1 = (max_data[0]-min_data[0])/gridno
inc2 = (max_data[1]-min_data[1])/gridno

# Make sure that np.arange(min_data[0], max_data[0]+inc1/2,inc1) returns an array of shape (41,)
gridx, gridy = np.meshgrid( np.arange(min_data[0], max_data[0]+inc1/2,inc1), np.arange(min_data[1], max_data[1]+inc2/2,inc2) )
# print(gridx.shape) #Output: (41,41) density

gridall = [gridx.flatten(order = 'F'), gridy.flatten(order = 'F')]
gridall = (np.asarray(gridall)).T
#print(gridall.shape) #--> (1681, 2), the 1681 pairs of (x,y)

def gaussian_kernel(x):
    return (1/np.sqrt(2*np.pi))*(np.e**(-(sum(x**2))/2))

def kde(xy, x_all, h):
    px = 0
    for x_i in x_all:
        px += 1/h*gaussian_kernel((x_i-xy)/h)

    return px/len(x_all)


h = 0.008


px_all = []
for xy in gridall:
    px = kde(xy, data, h)
    px_all.append(px)
####
#px_all = (px_all-px_all.min())/(px_all.max()-px_all.min())
#values = np.vstack([amy, acc])
#px_all = stats.gaussian_kde(values)
mkde = np.reshape(px_all, gridx.shape)
#mkde = (mkde-mkde.min())/(mkde.max()-mkde.min())
#scaling_factor = 1/inc1
#mkde = mkde/scaling_factor

fig = plt.figure()
ax=fig.add_subplot(111, projection='3d')
ax.plot_surface(gridx, gridy, mkde,cmap=cm.coolwarm)
plt.title("h = 0.008", fontsize=20)
plt.xlabel("Amygdala",fontsize=10)
plt.ylabel("Acc",fontsize=10)
plt.show()

# %%
mkde
# Out:
# array([[1.92063487e-02, 3.26409162e-02, 5.19699668e-02, ...,
#         1.86598862e-01, 1.47653816e-01, 1.07606588e-01],
#        [4.12439584e-02, 6.96756640e-02, 1.09975621e-01, ...,
#         3.16713162e-01, 2.49925078e-01, 1.81761259e-01],
#        [7.16053616e-02, 1.20359690e-01, 1.88583322e-01, ...,
#         4.36661464e-01, 3.42629654e-01, 2.48198018e-01],
#        ...,
#        [8.83634243e-02, 1.51612163e-01, 2.40548183e-01, ...,
#         2.08064249e-05, 1.72671827e-05, 1.42061934e-05],
#        [6.92385915e-02, 1.20649908e-01, 1.95081402e-01, ...,
#         3.56128318e-06, 2.17175345e-06, 1.60363335e-06],
#        [4.56501547e-02, 8.15470583e-02, 1.35760056e-01, ...,
#         9.65326792e-07, 3.39283023e-07, 1.71489363e-07]])

# %%
xmin = amy.min()
xmax = amy.max()
ymin = acc.min()
ymax = acc.max()

X, Y = np.mgrid[xmin:xmax:100j, ymin:ymax:100j]
positions = np.vstack([X.ravel(), Y.ravel()])
values = np.vstack([amy, acc])
kernel = stats.gaussian_kde(values)
kernel.set_bandwidth(bw_method=.5)
Z = np.reshape(kernel(positions).T, X.shape)

from mpl_toolkits.axes_grid1 import make_axes_locatable


fig, ax = plt.subplots()

divider = make_axes_locatable(ax)
ax_cb = divider.new_horizontal(size="5%", pad=0.05)
fig.add_axes(ax_cb)


im = ax.imshow(np.rot90(Z), cmap= 'CMRmap',
          extent=[xmin, xmax, ymin, ymax])

plt.colorbar(im, cax=ax_cb)

#ax.plot(amy, acc, 'k.', markersize=2)
ax.set_xlim([xmin, xmax])
ax.set_ylim([ymin, ymax])
ax.set_title('KDE contour plot p(amygdala,acc)')
ax.set_xlabel('Amygdala')
ax.set_ylabel('Acc')
plt.show()

# %%
Z.shape
# Out:
# (100, 100)

# %%
from sklearn.neighbors import KernelDensity
amy = amy.reshape(1,-1)
kde_amy = KernelDensity(kernel='gaussian', bandwidth=0.6).fit(amy)
kde_amy
s = np.linspace(0,1)
e = kde_amy.score_samples(amy)
e
# Out:
# array([-36.73016185])

# %%
ind = np.linspace(xmin,xmax,100)
kernel_amy = stats.gaussian_kde(amy)
kernel_amy.set_bandwidth(bw_method=.5)
kdepdf = kernel_amy.evaluate(ind)
plt.figure()
plt.plot(ind, stats.norm.pdf(ind), color="r", label='DGP normal')
# plot estimated density
plt.plot(ind, kdepdf, label='kde', color="g")
plt.title('Kernel Density Estimation')
plt.legend()
#plt.show()
amy_kde =kdepdf

# %%
amy_kde
# Out:
# array([ 2.54476971,  2.70239922,  2.85485616,  3.00126968,  3.14111744,
#         3.27427118,  3.40102672,  3.52211567,  3.63869761,  3.75233203,
#         3.86493091,  3.97869368,  4.09602737,  4.21945576,  4.35152189,
#         4.49468839,  4.65124047,  4.82319587,  5.01222541,  5.21958723,
#         5.44607673,  5.69199304,  5.95712227,  6.24073662,  6.54160782,
#         6.85803306,  7.18787112,  7.52858672,  7.877301  ,  8.2308467 ,
#         8.58582675,  8.93867554,  9.28572249,  9.6232576 ,  9.9475987 ,
#        10.25516016, 10.54252228, 10.80650024, 11.04421105, 11.25313638,
#        11.43117887, 11.57670923, 11.68860135, 11.76625326, 11.80959162,
#        11.81905893, 11.79558289, 11.74052886, 11.65563721, 11.5429484 ,
#        11.40471954, 11.24333686, 11.06122858, 10.86078323, 10.6442774 ,
#        10.41381698, 10.17129442,  9.91836385,  9.6564345 ,  9.3866814 ,
#         9.11007177,  8.82740384,  8.53935459,  8.24653226,  7.94952946,
# ...

# %%
ind = np.linspace(ymin,ymax,100)
kernel_acc = stats.gaussian_kde(acc)
kernel_acc.set_bandwidth(bw_method=.5)

kdepdf_acc = kernel_acc.evaluate(ind)
plt.figure()
plt.plot(ind, stats.norm.pdf(ind), color="r", label='DGP normal')
# plot estimated density
plt.plot(ind, kdepdf_acc, label='kde', color="g")
plt.title('Kernel Density Estimation')
plt.legend()
#plt.show()
acc_kde =kdepdf_acc

# %%
acc_kde
# Out:
# array([ 3.89557109,  4.32893904,  4.78794594,  5.27142626,  5.77798475,
#         6.30603497,  6.85384047,  7.41955507,  8.00125827,  8.59698218,
#         9.20472663,  9.82246022, 10.44810601, 11.07951228, 11.71441007,
#        12.35036111, 12.9847007 , 13.61448179, 14.2364265 , 14.84689194,
#        15.44185645, 16.01693136, 16.56740178, 17.08829781, 17.57449556,
#        18.02084459, 18.42231657, 18.77416783, 19.07210707, 19.31245884,
#        19.49231312, 19.609652  , 19.66344575, 19.65371206, 19.58153495,
#        19.44904154, 19.25933808, 19.01640829, 18.72497966, 18.39036456,
#        18.01828441, 17.61468555, 17.18555568, 16.73674905, 16.27382794,
#        15.80192646, 15.3256414 , 14.84895325, 14.37517872, 13.90695459,
#        13.44625137, 12.99441361, 12.55222318, 12.11998045, 11.69759841,
#        11.28470387, 10.88074054, 10.4850685 , 10.09705554,  9.71615626,
#         9.34197581,  8.97431626,  8.61320435,  8.25890084,  7.91189234,
# ...

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
Z_amy_acc = np.outer(amy_kde,acc_kde)

#positions = np.vstack([X.ravel(), Y.ravel()])
#values = np.vstack([amy, acc])
#kernel_acc = stats.gaussian_kde(acc)
#Z = np.outer(kernel_amy,kernel_amy)
fig, ax = plt.subplots()

divider = make_axes_locatable(ax)
ax_cb = divider.new_horizontal(size="5%", pad=0.05)
fig.add_axes(ax_cb)


im = ax.imshow(np.rot90(Z_amy_acc), cmap= 'CMRmap',
          extent=[xmin, xmax, ymin, ymax])

plt.colorbar(im, cax=ax_cb)

#ax.plot(amy, acc, 'k.', markersize=2)
ax.set_xlim([xmin, xmax])
ax.set_ylim([ymin, ymax])
ax.set_title('KDE contour plot of p(amygdala)p(acc)')
ax.set_xlabel('Amygdala')
ax.set_ylabel('Acc')
plt.show()

# %%
Z_amy_acc.shape
# Out:
# (100, 100)

# %%
Z_error = abs(Z-Z_amy_acc)

#positions = np.vstack([X.ravel(), Y.ravel()])
#values = np.vstack([amy, acc])
#kernel_acc = stats.gaussian_kde(acc)
#Z = np.outer(kernel_amy,kernel_amy)
fig, ax = plt.subplots()

divider = make_axes_locatable(ax)
ax_cb = divider.new_horizontal(size="5%", pad=0.05)
fig.add_axes(ax_cb)

im= ax.imshow(np.rot90(Z_error), cmap= 'CMRmap',
          extent=[xmin, xmax, ymin, ymax])

plt.colorbar(im, cax=ax_cb)

#ax.plot(amy, acc, 'k.', markersize=2)
ax.set_xlim([xmin, xmax])
ax.set_ylim([ymin, ymax])
ax.set_title('KDE contour plot of error = p(amygdala,acc) - p(amygdala)p(acc)')
ax.set_xlabel('Amygdala')
ax.set_ylabel('Acc')
plt.show()

# %%
Z_error.max()
# Out:
# 25.38462403780312

# %%
#p(amy)
gridx_amy = np.meshgrid( np.arange(min_data[0], max_data[0]+inc1/2,inc1))
gridall_amy = gridx_amy
gridall_amy = (np.asarray(gridall_amy)).T

px_amy = []
for xy in gridall_amy:
    
    px = kde(xy, data[:,0], h)
    px_amy.append(px)
print(len(px_amy))
#myInt = 41
#px_amy = [x *inc1 for x in px_amy]
# Out:
# 41

# %%
px_acc_try = stats.gaussian_kde(acc)

# %%
#p(acc)
gridx_acc= np.meshgrid( np.arange(min_data[1], max_data[1]+inc2/2,inc2))
gridall_acc = gridx_acc
gridall_acc = (np.asarray(gridall_acc)).T

px_acc = []
for xy in gridall_acc:

    px = kde(xy, data[:,1], h)
    px_acc.append(px)
#print(len(px_amy))
#myInt = 41
#px_acc = [x*inc2 for x in px_acc]

# %%
for i in range(2,6):
    #amygdala_data = data[np.where(y == i),0].reshape(-1)
    amy_x = df[df['orientation']==i]['amygdala']
    #Default kernel='gau'
    sns.kdeplot(amy_x)
    
plt.legend(labels=['Orientation 2', 'Orientation 3', 'Orientation 4', "Orientation 5"])
plt.title("Conditional KDE of Amygdala given orientation", fontsize=10)
plt.xlabel("Amygdala",fontsize=10)

plt.show()
# Out:
# C:\Users\rebec\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\rebec\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# ...

# %%
for i in range(2,6):
    #amygdala_data = data[np.where(y == i),0].reshape(-1)
    acc_x = df[df['orientation']==i]['acc']
    #Default kernel='gau'
    sns.kdeplot(acc_x)
    
plt.legend(labels=['Orientation 2', 'Orientation 3', 'Orientation 4', "Orientation 5"])
plt.title("Conditional KDE of Acc given orientation", fontsize=10)
plt.xlabel("Acc",fontsize=10)
plt.show()
# Out:
# C:\Users\rebec\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\rebec\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# ...

# %%
sns.kdeplot(df["amygdala"],df["acc"], cmap="mako", cbar=True)
plt.title("Joint KDE of Amygdala and Acc", fontsize=15)
plt.xlabel("Amygdala",fontsize=10)
plt.ylabel("Acc",fontsize=10)
plt.show()
# Out:
# C:\Users\rebec\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
acc_x = df[df['orientation']==2]['acc']
amy_x = df[df['orientation']==2]['amygdala']
#Default kernel='gau'
sns.kdeplot(amy_x,acc_x, cmap="mako", cbar=True)
    
#plt.legend(labels=['Orientation 2', 'Orientation 3', 'Orientation 4', "Orientation 5"])
plt.title("Conditional joint KDE of Amygdala and Acc, Orientation = 2", fontsize=15)
plt.xlabel("Amygdala",fontsize=10)
plt.ylabel("Acc",fontsize=10)
plt.show()

# %%
acc_x = df[df['orientation']==3]['acc']
amy_x = df[df['orientation']==3]['amygdala']
#Default kernel='gau'
sns.kdeplot(amy_x,acc_x, cmap="mako", cbar=True)
    
#plt.legend(labels=['Orientation 2', 'Orientation 3', 'Orientation 4', "Orientation 5"])
plt.title("Conditional joint KDE of Amygdala and Acc, Orientation = 3", fontsize=15)
plt.xlabel("Amygdala",fontsize=10)
plt.ylabel("Acc",fontsize=10)
plt.show()

# %%
acc_x = df[df['orientation']==4]['acc']
amy_x = df[df['orientation']==4]['amygdala']
#Default kernel='gau'
sns.kdeplot(amy_x,acc_x, cmap="mako", cbar=True)
    
#plt.legend(labels=['Orientation 2', 'Orientation 3', 'Orientation 4', "Orientation 5"])
plt.title("Conditional joint KDE of Amygdala and Acc, Orientation = 4", fontsize=15)
plt.xlabel("Amygdala",fontsize=10)
plt.ylabel("Acc",fontsize=10)
plt.show()

# %%
acc_x = df[df['orientation']==5]['acc']
amy_x = df[df['orientation']==5]['amygdala']
#Default kernel='gau'
sns.kdeplot(amy_x,acc_x, cmap="mako", cbar=True)
    
#plt.legend(labels=['Orientation 2', 'Orientation 3', 'Orientation 4', "Orientation 5"])
plt.title("Conditional joint KDE of Amygdala and Acc, Orientation = ", fontsize=15)
plt.xlabel("Amygdala",fontsize=10)
plt.ylabel("Acc",fontsize=10)
plt.show()

# %%
fig, axes = plt.subplots(ncols=2, nrows=2)

for i, ax in zip(range(2,6), axes.flat):
    acc_x = df[df['orientation']==i]['acc']
    amy_x = df[df['orientation']==i]['amygdala']
    #Default kernel='gau'
    sns.kdeplot(amy_x,acc_x, cmap="mako",ax=ax)
plt.show()

# %%
#for i in range(2:6):
df_2 =  df[(df['orientation']==2)]
amy = df_2["amygdala"].values
acc = df_2["acc"].values

xmin = amy.min()-.04
xmax = amy.max()+.04
ymin = acc.min()-.02
ymax = acc.max()+.02

X, Y = np.mgrid[xmin:xmax:100j, ymin:ymax:100j]
positions = np.vstack([X.ravel(), Y.ravel()])
values = np.vstack([amy, acc])
kernel = stats.gaussian_kde(values)
kernel.set_bandwidth(bw_method=.7)
Z = np.reshape(kernel(positions).T, X.shape)
           
           
fig, ax = plt.subplots()

divider = make_axes_locatable(ax)
ax_cb = divider.new_horizontal(size="5%", pad=0.05)
fig.add_axes(ax_cb)


im = ax.imshow(np.rot90(Z), cmap= 'CMRmap',
          extent=[xmin, xmax, ymin, ymax])

plt.colorbar(im, cax=ax_cb)

#ax.plot(amy, acc, 'k.', markersize=2)
ax.set_xlim([xmin, xmax])
ax.set_ylim([ymin, ymax])
ax.set_title('Conditional KDE contour plot of p(Amygdala,Acc), orientation=2')
ax.set_xlabel('Amygdala')
ax.set_ylabel('Acc')
plt.show()
           
ind = np.linspace(xmin,xmax,100)
kernel_amy = stats.gaussian_kde(amy)
kernel_amy.set_bandwidth(bw_method=.7)
kdepdf = kernel_amy.evaluate(ind)
plt.figure()
plt.plot(ind, stats.norm.pdf(ind), color="r", label='DGP normal')
# plot estimated density
plt.plot(ind, kdepdf, label='kde', color="g")
plt.title('Kernel Density Estimation')
plt.legend()
#plt.show()
amy_kde =kdepdf
           
ind = np.linspace(ymin,ymax,100)
kernel_acc = stats.gaussian_kde(acc)
kernel_acc.set_bandwidth(bw_method=.7)

kdepdf_acc = kernel_acc.evaluate(ind)
plt.figure()
plt.plot(ind, stats.norm.pdf(ind), color="r", label='DGP normal')
# plot estimated density
plt.plot(ind, kdepdf_acc, label='kde', color="g")
plt.title('Kernel Density Estimation')
plt.legend()
#plt.show()
acc_kde =kdepdf_acc

Z_amy_acc = np.outer(amy_kde,acc_kde)

#positions = np.vstack([X.ravel(), Y.ravel()])
#values = np.vstack([amy, acc])
#kernel_acc = stats.gaussian_kde(acc)
#Z = np.outer(kernel_amy,kernel_amy)
fig, ax = plt.subplots()

divider = make_axes_locatable(ax)
ax_cb = divider.new_horizontal(size="5%", pad=0.05)
fig.add_axes(ax_cb)


im = ax.imshow(np.rot90(Z_amy_acc), cmap= 'CMRmap',
          extent=[xmin, xmax, ymin, ymax])

plt.colorbar(im, cax=ax_cb)

#ax.plot(amy, acc, 'k.', markersize=2)
ax.set_xlim([xmin, xmax])
ax.set_ylim([ymin, ymax])
ax.set_title('KDE contour plot of p(Amygdala)p(Acc), orientation=2')
ax.set_xlabel('Amygdala')
ax.set_ylabel('Acc')
plt.show()
           
Z_error = abs(Z-Z_amy_acc)

#positions = np.vstack([X.ravel(), Y.ravel()])
#values = np.vstack([amy, acc])
#kernel_acc = stats.gaussian_kde(acc)
#Z = np.outer(kernel_amy,kernel_amy)
fig, ax = plt.subplots()


divider = make_axes_locatable(ax)
ax_cb = divider.new_horizontal(size="5%", pad=0.05)
fig.add_axes(ax_cb)

im= ax.imshow(np.rot90(Z_error), cmap='CMRmap',
          extent=[xmin, xmax, ymin, ymax])
plt.colorbar(im, cax=ax_cb)


#ax.plot(amy, acc, 'k.', markersize=2)
ax.set_xlim([xmin, xmax])
ax.set_ylim([ymin, ymax])
ax.set_title('Conditional KDE contour plot of Error, orientation=2')
ax.set_xlabel('Amygdala')
ax.set_ylabel('Acc')
plt.show()

# %%
#for i in range(2:6):
df_3 =  df[(df['orientation']==3)]
amy = df_3["amygdala"].values
acc = df_3["acc"].values

xmin = amy.min()-.02
xmax = amy.max()
ymin = acc.min()-.02
ymax = acc.max()+.01

X, Y = np.mgrid[xmin:xmax:100j, ymin:ymax:100j]
positions = np.vstack([X.ravel(), Y.ravel()])
values = np.vstack([amy, acc])
kernel = stats.gaussian_kde(values)
kernel.set_bandwidth(bw_method=.7)
Z = np.reshape(kernel(positions).T, X.shape)
           
           
fig, ax = plt.subplots()

divider = make_axes_locatable(ax)
ax_cb = divider.new_horizontal(size="5%", pad=0.05)
fig.add_axes(ax_cb)


im = ax.imshow(np.rot90(Z), cmap= 'CMRmap',
          extent=[xmin, xmax, ymin, ymax])

plt.colorbar(im, cax=ax_cb)

#ax.plot(amy, acc, 'k.', markersize=2)
ax.set_xlim([xmin, xmax])
ax.set_ylim([ymin, ymax])
ax.set_title('Conditional KDE contour plot of p(Amygdala,Acc), orientation=3')
ax.set_xlabel('Amygdala')
ax.set_ylabel('Acc')
plt.show()
           
ind = np.linspace(xmin,xmax,100)
kernel_amy = stats.gaussian_kde(amy)
kernel_amy.set_bandwidth(bw_method=.7)
kdepdf = kernel_amy.evaluate(ind)
plt.figure()
plt.plot(ind, stats.norm.pdf(ind), color="r", label='DGP normal')
# plot estimated density
plt.plot(ind, kdepdf, label='kde', color="g")
plt.title('Kernel Density Estimation')
plt.legend()
#plt.show()
amy_kde =kdepdf
           
ind = np.linspace(ymin,ymax,100)
kernel_acc = stats.gaussian_kde(acc)
kernel_acc.set_bandwidth(bw_method=.7)

kdepdf_acc = kernel_acc.evaluate(ind)
plt.figure()
plt.plot(ind, stats.norm.pdf(ind), color="r", label='DGP normal')
# plot estimated density
plt.plot(ind, kdepdf_acc, label='kde', color="g")
plt.title('Kernel Density Estimation')
plt.legend()
#plt.show()
acc_kde =kdepdf_acc

Z_amy_acc = np.outer(amy_kde,acc_kde)

#positions = np.vstack([X.ravel(), Y.ravel()])
#values = np.vstack([amy, acc])
#kernel_acc = stats.gaussian_kde(acc)
#Z = np.outer(kernel_amy,kernel_amy)
fig, ax = plt.subplots()

divider = make_axes_locatable(ax)
ax_cb = divider.new_horizontal(size="5%", pad=0.05)
fig.add_axes(ax_cb)


im = ax.imshow(np.rot90(Z_amy_acc), cmap= 'CMRmap',
          extent=[xmin, xmax, ymin, ymax])

plt.colorbar(im, cax=ax_cb)

#ax.plot(amy, acc, 'k.', markersize=2)
ax.set_xlim([xmin, xmax])
ax.set_ylim([ymin, ymax])
ax.set_title('KDE contour plot of p(Amygdala)p(Acc), orientation=3')
ax.set_xlabel('Amygdala')
ax.set_ylabel('Acc')
plt.show()
           
Z_error = abs(Z-Z_amy_acc)

#positions = np.vstack([X.ravel(), Y.ravel()])
#values = np.vstack([amy, acc])
#kernel_acc = stats.gaussian_kde(acc)
#Z = np.outer(kernel_amy,kernel_amy)
fig, ax = plt.subplots()


divider = make_axes_locatable(ax)
ax_cb = divider.new_horizontal(size="5%", pad=0.05)
fig.add_axes(ax_cb)

im= ax.imshow(np.rot90(Z_error), cmap='CMRmap',
          extent=[xmin, xmax, ymin, ymax])
plt.colorbar(im, cax=ax_cb)


#ax.plot(amy, acc, 'k.', markersize=2)
ax.set_xlim([xmin, xmax])
ax.set_ylim([ymin, ymax])
ax.set_title('Conditional KDE contour plot of Error, orientation=3')
ax.set_xlabel('Amygdala')
ax.set_ylabel('Acc')
plt.show()

# %%
#for i in range(2:6):
df_4 =  df[(df['orientation']==4)]
amy = df_4["amygdala"].values
acc = df_4["acc"].values

xmin = amy.min()-.02
xmax = amy.max()
ymin = acc.min()-.02
ymax = acc.max()

X, Y = np.mgrid[xmin:xmax:100j, ymin:ymax:100j]
positions = np.vstack([X.ravel(), Y.ravel()])
values = np.vstack([amy, acc])
kernel = stats.gaussian_kde(values)
kernel.set_bandwidth(bw_method=.7)
Z = np.reshape(kernel(positions).T, X.shape)
           
           
fig, ax = plt.subplots()

divider = make_axes_locatable(ax)
ax_cb = divider.new_horizontal(size="5%", pad=0.05)
fig.add_axes(ax_cb)


im = ax.imshow(np.rot90(Z), cmap= 'CMRmap',
          extent=[xmin, xmax, ymin, ymax])

plt.colorbar(im, cax=ax_cb)

#ax.plot(amy, acc, 'k.', markersize=2)
ax.set_xlim([xmin, xmax])
ax.set_ylim([ymin, ymax])
ax.set_title('Conditional KDE contour plot of p(Amygdala,Acc), orientation=4')
ax.set_xlabel('Amygdala')
ax.set_ylabel('Acc')
plt.show()
           
ind = np.linspace(xmin,xmax,100)
kernel_amy = stats.gaussian_kde(amy)
kernel_amy.set_bandwidth(bw_method=.7)
kdepdf = kernel_amy.evaluate(ind)
plt.figure()
plt.plot(ind, stats.norm.pdf(ind), color="r", label='DGP normal')
# plot estimated density
plt.plot(ind, kdepdf, label='kde', color="g")
plt.title('Kernel Density Estimation')
plt.legend()
#plt.show()
amy_kde =kdepdf
           
ind = np.linspace(ymin,ymax,100)
kernel_acc = stats.gaussian_kde(acc)
kernel_acc.set_bandwidth(bw_method=.7)

kdepdf_acc = kernel_acc.evaluate(ind)
plt.figure()
plt.plot(ind, stats.norm.pdf(ind), color="r", label='DGP normal')
# plot estimated density
plt.plot(ind, kdepdf_acc, label='kde', color="g")
plt.title('Kernel Density Estimation')
plt.legend()
#plt.show()
acc_kde =kdepdf_acc

Z_amy_acc = np.outer(amy_kde,acc_kde)

#positions = np.vstack([X.ravel(), Y.ravel()])
#values = np.vstack([amy, acc])
#kernel_acc = stats.gaussian_kde(acc)
#Z = np.outer(kernel_amy,kernel_amy)
fig, ax = plt.subplots()

divider = make_axes_locatable(ax)
ax_cb = divider.new_horizontal(size="5%", pad=0.05)
fig.add_axes(ax_cb)


im = ax.imshow(np.rot90(Z_amy_acc), cmap= 'CMRmap',
          extent=[xmin, xmax, ymin, ymax])

plt.colorbar(im, cax=ax_cb)

#ax.plot(amy, acc, 'k.', markersize=2)
ax.set_xlim([xmin, xmax])
ax.set_ylim([ymin, ymax])
ax.set_title('KDE contour plot of p(Amygdala)p(Acc), orientation=4')
ax.set_xlabel('Amygdala')
ax.set_ylabel('Acc')
plt.show()
           
Z_error = abs(Z-Z_amy_acc)

#positions = np.vstack([X.ravel(), Y.ravel()])
#values = np.vstack([amy, acc])
#kernel_acc = stats.gaussian_kde(acc)
#Z = np.outer(kernel_amy,kernel_amy)
fig, ax = plt.subplots()


divider = make_axes_locatable(ax)
ax_cb = divider.new_horizontal(size="5%", pad=0.05)
fig.add_axes(ax_cb)

im= ax.imshow(np.rot90(Z_error), cmap='CMRmap',
          extent=[xmin, xmax, ymin, ymax])
plt.colorbar(im, cax=ax_cb)


#ax.plot(amy, acc, 'k.', markersize=2)
ax.set_xlim([xmin, xmax])
ax.set_ylim([ymin, ymax])
ax.set_title('Conditional KDE contour plot of Error, orientation=4')
ax.set_xlabel('Amygdala')
ax.set_ylabel('Acc')
plt.show()

# %%
#for i in range(2:6):
df_5 =  df[(df['orientation']==5)]
amy = df_5["amygdala"].values
acc = df_5["acc"].values

xmin = amy.min()-.02
xmax = amy.max()+.02
ymin = acc.min()-.02
ymax = acc.max()

X, Y = np.mgrid[xmin:xmax:100j, ymin:ymax:100j]
positions = np.vstack([X.ravel(), Y.ravel()])
values = np.vstack([amy, acc])
kernel = stats.gaussian_kde(values)
kernel.set_bandwidth(bw_method=.6)
Z = np.reshape(kernel(positions).T, X.shape)
           
           
fig, ax = plt.subplots()

divider = make_axes_locatable(ax)
ax_cb = divider.new_horizontal(size="5%", pad=0.05)
fig.add_axes(ax_cb)


im = ax.imshow(np.rot90(Z), cmap= 'CMRmap',
          extent=[xmin, xmax, ymin, ymax])

plt.colorbar(im, cax=ax_cb)

#ax.plot(amy, acc, 'k.', markersize=2)
ax.set_xlim([xmin, xmax])
ax.set_ylim([ymin, ymax])
ax.set_title('Conditional KDE contour plot of p(Amygdala,Acc), orientation=5')
ax.set_xlabel('Amygdala')
ax.set_ylabel('Acc')
plt.show()
           
ind = np.linspace(xmin,xmax,100)
kernel_amy = stats.gaussian_kde(amy)
kernel_amy.set_bandwidth(bw_method=.8)
kdepdf = kernel_amy.evaluate(ind)
plt.figure()
plt.plot(ind, stats.norm.pdf(ind), color="r", label='DGP normal')
# plot estimated density
plt.plot(ind, kdepdf, label='kde', color="g")
plt.title('Kernel Density Estimation')
plt.legend()
#plt.show()
amy_kde =kdepdf
           
ind = np.linspace(ymin,ymax,100)
kernel_acc = stats.gaussian_kde(acc)
kernel_acc.set_bandwidth(bw_method=.8)

kdepdf_acc = kernel_acc.evaluate(ind)
plt.figure()
plt.plot(ind, stats.norm.pdf(ind), color="r", label='DGP normal')
# plot estimated density
plt.plot(ind, kdepdf_acc, label='kde', color="g")
plt.title('Kernel Density Estimation')
plt.legend()
#plt.show()
acc_kde =kdepdf_acc

Z_amy_acc = np.outer(amy_kde,acc_kde)

#positions = np.vstack([X.ravel(), Y.ravel()])
#values = np.vstack([amy, acc])
#kernel_acc = stats.gaussian_kde(acc)
#Z = np.outer(kernel_amy,kernel_amy)
fig, ax = plt.subplots()

divider = make_axes_locatable(ax)
ax_cb = divider.new_horizontal(size="5%", pad=0.05)
fig.add_axes(ax_cb)


im = ax.imshow(np.rot90(Z_amy_acc), cmap= 'CMRmap',
          extent=[xmin, xmax, ymin, ymax])

plt.colorbar(im, cax=ax_cb)

#ax.plot(amy, acc, 'k.', markersize=2)
ax.set_xlim([xmin, xmax])
ax.set_ylim([ymin, ymax])
ax.set_title('KDE contour plot of p(Amygdala)p(Acc), orientation=5')
ax.set_xlabel('Amygdala')
ax.set_ylabel('Acc')
plt.show()
           
Z_error = abs(Z-Z_amy_acc)

#positions = np.vstack([X.ravel(), Y.ravel()])
#values = np.vstack([amy, acc])
#kernel_acc = stats.gaussian_kde(acc)
#Z = np.outer(kernel_amy,kernel_amy)
fig, ax = plt.subplots()


divider = make_axes_locatable(ax)
ax_cb = divider.new_horizontal(size="5%", pad=0.05)
fig.add_axes(ax_cb)

im= ax.imshow(np.rot90(Z_error), cmap='CMRmap',
          extent=[xmin, xmax, ymin, ymax])
plt.colorbar(im, cax=ax_cb)


#ax.plot(amy, acc, 'k.', markersize=2)
ax.set_xlim([xmin, xmax])
ax.set_ylim([ymin, ymax])
ax.set_title('Conditional KDE contour plot of Error, orientation=5')
ax.set_xlabel('Amygdala')
ax.set_ylabel('Acc')
plt.show()
